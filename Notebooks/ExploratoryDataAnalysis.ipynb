# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../DataSets/UCI_ObesityDataSet.csv")

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Description
# This dataset from the UCI machine learning repository contatins <b>behavioral</b> and <b>lifestyle</b> factors reported in an online survey by individuals (<b>age 14–61</b>) from <b>Peru</b>, <b>Mexico</b>, and <b>Colombia</b>.

# %% [markdown]
# # Data Quality Check

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
df[ df.duplicated() ]
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 98   Female  21.0    1.52    42.0                             no   no   3.0
# 106  Female  25.0    1.57    55.0                             no  yes   2.0
# 174    Male  21.0    1.62    70.0                             no  yes   2.0
# 179    Male  21.0    1.62    70.0                             no  yes   2.0
# 184    Male  21.0    1.62    70.0                             no  yes   2.0
# 209  Female  22.0    1.69    65.0                            yes  yes   2.0
# 309  Female  16.0    1.66    58.0                             no   no   2.0
# 460  Female  18.0    1.62    55.0                            yes  yes   2.0
# 467    Male  22.0    1.74    75.0                            yes  yes   3.0
# 496    Male  18.0    1.72    53.0                            yes  yes   2.0
# 527  Female  21.0    1.52    42.0                             no  yes   3.0
# ...

# %% [markdown]
# ### Note on Duplicates
#
# Although some rows in the dataset appear as duplicates, it is not appropriate to remove them. This is because the dataset does not contain a unique identifier or primary key to distinguish individual respondents.

# %%
sns.pairplot(df, vars = ['Age', 'Height', 'Weight'])

# %% [markdown]
# ### From pair plot we see that the age is largely distributed in the early to mid twenties and is not a good representation of individuals age 25+

# %% [markdown]
# ### Even representation of obesity classes

# %%
plt.figure(figsize=(14,10))
sns.histplot(df, x = 'NObeyesdad', hue = 'NObeyesdad')
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='Count'>

# %% [markdown]
# ### Idenitfy Categories per column

# %%
df['CAEC'].value_counts() # snack between meals column
# Out:
# CAEC
# Sometimes     1765
# Frequently     242
# Always          53
# no              51
# Name: count, dtype: int64

# %% [markdown]
# ### Getting values of each categorical column

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"\n--- {col} ---")
    print(df[col].value_counts())
# Out:
# --- Gender ---
# Gender
# Male      1068
# Female    1043
# Name: count, dtype: int64
#
# --- family_history_with_overweight ---
# family_history_with_overweight
# yes    1726
# no      385
# Name: count, dtype: int64
#
# --- FAVC ---
# FAVC
# yes    1866
# no      245
# Name: count, dtype: int64
#
# --- CAEC ---
# CAEC
# Sometimes     1765
# Frequently     242
# Always          53
# no              51
# Name: count, dtype: int64
#
# --- SMOKE ---
# SMOKE
# no     2067
# yes      44
# Name: count, dtype: int64
#
# --- SCC ---
# SCC
# no     2015
# yes      96
# Name: count, dtype: int64
#
# --- CALC ---
# CALC
# Sometimes     1401
# no             639
# Frequently      70
# Always           1
# Name: count, dtype: int64
#
# --- MTRANS ---
# MTRANS
# Public_Transportation    1580
# Automobile                457
# Walking                    56
# Motorbike                  11
# Bike                        7
# Name: count, dtype: int64
#
# --- NObeyesdad ---
# NObeyesdad
# ...

# %% [markdown]
# # Data Reformatting and Enrichment

# %% [markdown]
# **Rename column labels for readability and intuitive data access**

# %%
# Rename labels for easy readability and intuitive data access. 
cleaned_df = df.rename(columns = {'Gender':'gender', 'Age':'age', 'Height':'height', 'Weight':'Weight','FAVC':'eat_high_calorie_frequently', 
                          'FCVC':'eat_vegetables_usually', 'NCP':'daily_meal_count', 'CAEC':'snack_between_meals', 'SMOKE':'smoke', 
                          'CH2O':'daily_water_intake', 'SCC':'monitor_calories', 'FAF':'activity_frequency', 'TUE':'time_on_technology', 
                          'CALC':'alcohol_frequency','MTRANS':'transportation', 'NObeyesdad':'obesity_level'})

# %%
# Removing underscores from Public Transportation
cleaned_df['transportation'] = cleaned_df['transportation'].astype('category')
cleaned_df['transportation'] = cleaned_df['transportation'].cat.rename_categories({'Public_Transportation': 'Public Transportation'})

# Removing unserscores from all obesity_level categories
cleaned_df['obesity_level'] = cleaned_df['obesity_level'].astype('category')
cleaned_df['obesity_level'] = cleaned_df['obesity_level'].cat.rename_categories({'Insufficient_Weight': 'Insufficient Weight',
                                                                 'Normal_Weight': 'Normal Weight',
                                                                'Overweight_Level_I': 'Overweight Level I',
                                                                'Overweight_Level_II': 'Overweight Level II',
                                                                'Obesity_Type_I': 'Obesity Type I',
                                                                'Obesity_Type_II': 'Obesity Type II',
                                                                'Obesity_Type_III': 'Obesity Type III'})

# %%
cleaned_df
# Out:
#       gender        age    height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %% [markdown]
# ### Adding BMI feature and Obesity (binary) feature

# %%
# add bmi feature 
cleaned_df['bmi'] = cleaned_df['Weight']/(cleaned_df['height']**2)

# add obese binary feature
cleaned_df['obese'] = (cleaned_df['bmi'] >= 30).astype(int)
cleaned_df
# Out:
#       gender        age    height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %% [markdown]
# ## Download Cleaned Dataframe

# %%
from IPython.display import FileLink

# Convert cleaned dataframe to csv
file_path = '../DataSets/cleaned_df.csv'
cleaned_df.to_csv(file_path, index=False)

# Download link for file
FileLink(file_path)
# Out:
# /Users/gerardogutierrez/Desktop/Academics/Spring_2025/CS_2410/finalproject/obesity-risk-analysis/DataSets/cleaned_df.csv
